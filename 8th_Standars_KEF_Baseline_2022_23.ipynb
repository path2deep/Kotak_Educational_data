# %% [markdown]
# <a href="https://colab.research.google.com/github/path2deep/Kotak_Educational_data/blob/main/8th_Standars_KEF_Baseline_2022_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import io
import seaborn as sns 
import matplotlib.pyplot as plt
from google.colab import files

# %% [markdown]
# ##uploading Assessments questions Report

# %% [markdown]
# ###Math

# %% [markdown]
# #####Math Marathi

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3f29b0c3-d8aa-4689-9868-b6b176648e9f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3f29b0c3-d8aa-4689-9868-b6b176648e9f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
file = io.BytesIO(uploaded.get("8th Std Semi with Marathi Math-Sci (Maths Baseline (Marathi)).xlsx"))
math1 = pd.read_excel(file, 'Report')

# %% [markdown]
# #####Math Semi Marathi

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-79676663-022f-432d-8fee-1242b4b59225" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-79676663-022f-432d-8fee-1242b4b59225">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
file = io.BytesIO(uploaded.get("8th Std Semi with Marathi Math-Sci (Maths Baseline (Semi)).xlsx"))
math2 = pd.read_excel(file, 'Report')

# %% [markdown]
# ###Science

# %% [markdown]
# ####Science Marathi

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a8d6eec7-0147-42cf-9d3e-b766fd90606d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a8d6eec7-0147-42cf-9d3e-b766fd90606d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
file = io.BytesIO(uploaded.get("8th Std Semi with Marathi Math-Sci (Science Baseline (Marathi)).xlsx"))
sci1 = pd.read_excel(file, 'Report')

# %% [markdown]
# ####Science Semi Marathi

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-12833ebe-96bf-4aee-b7f4-af600a187b02" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-12833ebe-96bf-4aee-b7f4-af600a187b02">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
file = io.BytesIO(uploaded.get("8th Std Semi with Marathi Math-Sci (Science Baseline (Semi)).xlsx"))
sci2 = pd.read_excel(file, 'Report')

# %% [markdown]
# ###English

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-88e0b039-bacd-468b-9c11-12dbf11f9f27" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-88e0b039-bacd-468b-9c11-12dbf11f9f27">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
file = io.BytesIO(uploaded.get("8th Std Semi with Marathi Math-Sci (English Baseline).xlsx"))
eng = pd.read_excel(file, 'Report')

# %% [markdown]
# ##Analysis

# %%
#combining all files
#math
math = pd.concat([math1, math2], ignore_index=True)
#science
sci = pd.concat([sci1, sci2], ignore_index=True)
#english


#Seclecting Columns
#Math
math = math[['School','EnrollmentID','StudentName','IndexNo',
             641690003,         641690004,         641690005,641690006,         641690007,         641690008,
             641690009,         641690010,         641690011,641690012,         641690013,         641690014,
             641690015,         641690016,         641690017,641690018,         641690019,         641690020,
             641690021,         641690022,         641690023,641690024,         641690025,         641690026,
             641690027,         641690028,         641690029,641690030,
             641689948,         641689949,                   641689950,         641689951,         641689952,
             641689953,         641689954,         641689955,641689956,         641689957,         641689958,
             641689959,         641689960,         641689961,641689962,         641689963,         641689964,
             641689965,         641689966,         641689967,641689968,         641689969,         641689970,
             641689971,         641689972,         641689973,641689974,         641689975
             ]] 

#Science
sci = sci[['School','EnrollmentID','StudentName','IndexNo',
           641690085,         641690086,         641690087,641690088,         641690089,         641690090,
           641690091,         641690092,         641690093,641690094,         641690095,         641690096,
           641690097,         641690098,         641690099,641690100,         641690101,         641690102,
           641690103,         641690104,         641690105,641690106,         641690107,         641690108,
           641690109,         641690110,         641690111,
           641690058,         641690059,         641690060,641690061,         641690062,         641690063,
           641690064,         641690065,         641690066,641690067,         641690068,         641690069,
           641690070,         641690071,         641690072,641690073,         641690074,         641690075,
           641690076,         641690077,         641690078,641690079,         641690080,         641690081,
           641690082,         641690083,         641690084]]

#English
eng = eng[['School','EnrollmentID','StudentName','IndexNo',
           641689913,         641689914,         641689915,641689916,         641689917,         641689918,
           641689919,         641689920,         641689921,641689922,         641689923,         641689924,
           641689925,         641689926,         641689927,641689928,         641689929,         641689930,
           641689931,         641689932,         641689933,641689934,         641689936,         641689937,
           641689938,         641689939,         641689940,641689941,         641689942,         641689943,
           641689944,         641689945,         641689946,641689947]]



#Mappging to the marks
#Math
#Marathi
math['641690003_Marks'] = [1 if x == 3 else 0 for x in math[641690003]]
math['641690004_Marks'] = [2 if x == 2 else 0 for x in math[641690004]]
math['641690005_Marks'] = [1 if x == 1 else 0 for x in math[641690005]]
math['641690006_Marks'] = [1 if x == 2 else 0 for x in math[641690006]]
math['641690007_Marks'] = [2 if x == 4 else 0 for x in math[641690007]]
math['641690008_Marks'] = [1 if x == 3 else 0 for x in math[641690008]]
math['641690009_Marks'] = [2 if x == 1 else 0 for x in math[641690009]]

math['641690010_Marks'] = [1 if x == 1 else 0 for x in math[641690010]]
math['641690011_Marks'] = [2 if x == 4 else 0 for x in math[641690011]]
math['641690012_Marks'] = [2 if x == 3 else 0 for x in math[641690012]]
math['641690013_Marks'] = [1 if x == 1 else 0 for x in math[641690013]]
math['641690014_Marks'] = [1 if x == 2 else 0 for x in math[641690014]]
math['641690015_Marks'] = [2 if x == 4 else 0 for x in math[641690015]]
math['641690016_Marks'] = [1 if x == 3 else 0 for x in math[641690016]]

math['641690017_Marks'] = [2 if x == 3 else 0 for x in math[641690017]]
math['641690018_Marks'] = [1 if x == 2 else 0 for x in math[641690018]]
math['641690019_Marks'] = [1 if x == 1 else 0 for x in math[641690019]]
math['641690020_Marks'] = [1 if x == 2 else 0 for x in math[641690020]]
math['641690021_Marks'] = [2 if x == 1 else 0 for x in math[641690021]]
math['641690022_Marks'] = [2 if x == 2 else 0 for x in math[641690022]]
math['641690023_Marks'] = [1 if x == 1 else 0 for x in math[641690023]]

math['641690024_Marks'] = [1 if x == 1 else 0 for x in math[641690024]]
math['641690025_Marks'] = [2 if x == 2 else 0 for x in math[641690025]]
math['641690026_Marks'] = [1 if x == 1 else 0 for x in math[641690026]]
math['641690027_Marks'] = [1 if x == 2 else 0 for x in math[641690027]]
math['641690028_Marks'] = [2 if x == 2 else 0 for x in math[641690028]]
math['641690029_Marks'] = [2 if x == 1 else 0 for x in math[641690029]]
math['641690030_Marks'] = [1 if x == 2 else 0 for x in math[641690030]]


#Semi Marathi

math['641689948_Marks'] = [1 if x == 3 else 0 for x in math[641689948]]
math['641689949_Marks'] = [2 if x == 2 else 0 for x in math[641689949]]
math['641689950_Marks'] = [1 if x == 1 else 0 for x in math[641689950]]
math['641689951_Marks'] = [1 if x == 2 else 0 for x in math[641689951]]
math['641689952_Marks'] = [2 if x == 4 else 0 for x in math[641689952]]
math['641689953_Marks'] = [1 if x == 3 else 0 for x in math[641689953]]
math['641689954_Marks'] = [2 if x == 1 else 0 for x in math[641689954]]

math['641689955_Marks'] = [1 if x == 1 else 0 for x in math[641689955]]
math['641689956_Marks'] = [2 if x == 4 else 0 for x in math[641689956]]
math['641689957_Marks'] = [2 if x == 3 else 0 for x in math[641689957]]
math['641689958_Marks'] = [1 if x == 1 else 0 for x in math[641689958]]
math['641689959_Marks'] = [1 if x == 2 else 0 for x in math[641689959]]
math['641689960_Marks'] = [2 if x == 4 else 0 for x in math[641689960]]
math['641689961_Marks'] = [1 if x == 3 else 0 for x in math[641689961]]

math['641689962_Marks'] = [2 if x == 3 else 0 for x in math[641689962]]
math['641689963_Marks'] = [1 if x == 2 else 0 for x in math[641689963]]
math['641689964_Marks'] = [1 if x == 1 else 0 for x in math[641689964]]
math['641689965_Marks'] = [2 if x == 2 else 0 for x in math[641689965]]
math['641689966_Marks'] = [2 if x == 1 else 0 for x in math[641689966]]
math['641689967_Marks'] = [1 if x == 2 else 0 for x in math[641689967]]
math['641689968_Marks'] = [1 if x == 1 else 0 for x in math[641689968]]

math['641689969_Marks'] = [1 if x == 1 else 0 for x in math[641689969]]
math['641689970_Marks'] = [2 if x == 1 else 0 for x in math[641689970]]
math['641689971_Marks'] = [1 if x == 1 else 0 for x in math[641689971]]
math['641689972_Marks'] = [1 if x == 2 else 0 for x in math[641689972]]
math['641689973_Marks'] = [2 if x == 2 else 0 for x in math[641689973]]
math['641689974_Marks'] = [2 if x == 1 else 0 for x in math[641689974]]
math['641689975_Marks'] = [1 if x == 2 else 0 for x in math[641689975]]

#Science

#Marathi
sci['641690085_Marks'] = [1 if x == 2 else 0 for x in sci[641690085]]
sci['641690086_Marks'] = [2 if x == 1 else 0 for x in sci[641690086]]
sci['641690087_Marks'] = [1 if x == 2 else 0 for x in sci[641690087]]
sci['641690088_Marks'] = [1 if x == 4 else 0 for x in sci[641690088]]
sci['641690089_Marks'] = [1 if x == 1 else 0 for x in sci[641690089]]
sci['641690090_Marks'] = [2 if x == 3 else 0 for x in sci[641690090]]
sci['641690091_Marks'] = [1 if x == 3 else 0 for x in sci[641690091]]

sci['641690092_Marks'] = [1 if x == 3 else 0 for x in sci[641690092]]
sci['641690093_Marks'] = [2 if x == 2 else 0 for x in sci[641690093]]
sci['641690094_Marks'] = [1 if x == 3 else 0 for x in sci[641690094]]
sci['641690095_Marks'] = [2 if x == 4 else 0 for x in sci[641690095]]
sci['641690096_Marks'] = [2 if x == 4 else 0 for x in sci[641690096]]
sci['641690097_Marks'] = [1 if x == 4 else 0 for x in sci[641690097]]
sci['641690098_Marks'] = [2 if x == 1 else 0 for x in sci[641690098]]

sci['641690099_Marks'] = [1 if x == 4 else 0 for x in sci[641690099]]
sci['641690100_Marks'] = [1 if x == 2 else 0 for x in sci[641690100]]
sci['641690101_Marks'] = [2 if x == 3 else 0 for x in sci[641690101]]
sci['641690102_Marks'] = [2 if x == 3 else 0 for x in sci[641690102]]
sci['641690103_Marks'] = [2 if x == 4 else 0 for x in sci[641690103]]
sci['641690104_Marks'] = [1 if x == 2 else 0 for x in sci[641690104]]
sci['641690105_Marks'] = [2 if x == 4 else 0 for x in sci[641690105]]

sci['641690106_Marks'] = [2 if x == 4 else 0 for x in sci[641690106]]
sci['641690107_Marks'] = [2 if x == 4 else 0 for x in sci[641690107]]
sci['641690107_Marks'] = [2 if x == 4 else 0 for x in sci[641690108]]
sci['641690109_Marks'] = [1 if x == 3 else 0 for x in sci[641690109]]
sci['641690110_Marks'] = [1 if x == 1 else 0 for x in sci[641690110]]
sci['641690111_Marks'] = [1 if x == 2 else 0 for x in sci[641690111]]


#Semi Marathi

sci['641690058_Marks'] = [1 if x == 2 else 0 for x in sci[641690058]]
sci['641690059_Marks'] = [2 if x == 1 else 0 for x in sci[641690059]]
sci['641690060_Marks'] = [1 if x == 2 else 0 for x in sci[641690060]]
sci['641690061_Marks'] = [1 if x == 4 else 0 for x in sci[641690061]]
sci['641690062_Marks'] = [2 if x == 3 else 0 for x in sci[641690062]]
sci['641690063_Marks'] = [1 if x == 1 else 0 for x in sci[641690063]]
sci['641690064_Marks'] = [1 if x == 1 else 0 for x in sci[641690064]]

sci['641690065_Marks'] = [2 if x == 4 else 0 for x in sci[641690065]]
sci['641690066_Marks'] = [1 if x == 3 else 0 for x in sci[641690066]]
sci['641690067_Marks'] = [2 if x == 4 else 0 for x in sci[641690067]]
sci['641690068_Marks'] = [2 if x == 4 else 0 for x in sci[641690068]]
sci['641690069_Marks'] = [1 if x == 4 else 0 for x in sci[641690069]]
sci['641690070_Marks'] = [2 if x == 1 else 0 for x in sci[641690070]]
sci['641690071_Marks'] = [1 if x == 4 else 0 for x in sci[641690071]]

sci['641690072_Marks'] = [1 if x == 2 else 0 for x in sci[641690072]]
sci['641690073_Marks'] = [2 if x == 3 else 0 for x in sci[641690073]]
sci['641690074_Marks'] = [2 if x == 3 else 0 for x in sci[641690074]]
sci['641690075_Marks'] = [2 if x == 4 else 0 for x in sci[641690075]]
sci['641690076_Marks'] = [1 if x == 2 else 0 for x in sci[641690076]]
sci['641690077_Marks'] = [2 if x == 4 else 0 for x in sci[641690077]]
sci['641690078_Marks'] = [2 if x == 4 else 0 for x in sci[641690078]]

sci['641690079_Marks'] = [1 if x == 4 else 0 for x in sci[641690079]]
sci['641690080_Marks'] = [2 if x == 4 else 0 for x in sci[641690080]]
sci['641690081_Marks'] = [1 if x == 3 else 0 for x in sci[641690081]]
sci['641690082_Marks'] = [1 if x == 1 else 0 for x in sci[641690082]]
sci['641690083_Marks'] = [1 if x == 2 else 0 for x in sci[641690083]]
sci['641690084_Marks'] = [1 if x == 1 else 0 for x in sci[641690084]]

#English
eng['641689913_Marks'] = [1 if x == 4 else 0 for x in eng[641689913]]
eng['641689914_Marks'] = [1 if x == 3 else 0 for x in eng[641689914]]
eng['641689915_Marks'] = [1 if x == 2 else 0 for x in eng[641689915]]
eng['641689916_Marks'] = [1 if x == 2 else 0 for x in eng[641689916]]
eng['641689917_Marks'] = [1 if x == 3 else 0 for x in eng[641689917]]
eng['641689918_Marks'] = [1 if x == 1 else 0 for x in eng[641689918]]
eng['641689919_Marks'] = [1 if x == 2 else 0 for x in eng[641689919]]

eng['641689920_Marks'] = [1 if x == 4 else 0 for x in eng[641689920]]

eng['641689921_Marks'] = [1 if x == 2 else 0 for x in eng[641689921]]
eng['641689922_Marks'] = [1 if x == 2 else 0 for x in eng[641689922]]
eng['641689923_Marks'] = [1 if x == 3 else 0 for x in eng[641689923]]
eng['641689924_Marks'] = [1 if x == 2 else 0 for x in eng[641689924]]
eng['641689925_Marks'] = [1 if x == 2 else 0 for x in eng[641689925]]
eng['641689926_Marks'] = [1 if x == 1 else 0 for x in eng[641689926]]
eng['641689927_Marks'] = [1 if x == 2 else 0 for x in eng[641689927]]
eng['641689928_Marks'] = [1 if x == 3 else 0 for x in eng[641689928]]
eng['641689929_Marks'] = [1 if x == 3 else 0 for x in eng[641689929]]
eng['641689930_Marks'] = [1 if x == 1 else 0 for x in eng[641689930]]
eng['641689931_Marks'] = [1 if x == 2 else 0 for x in eng[641689931]]

eng['641689932_Marks'] = [1 if x == 1 else 0 for x in eng[641689932]]
eng['641689933_Marks'] = [1 if x == 1 else 0 for x in eng[641689933]]
eng['641689934_Marks'] = [1 if x == 4 else 0 for x in eng[641689934]]
#eng['641689935_Marks'] = [2 if x == 2 else 0 for x in eng[641689935]]
eng['641689936_Marks'] = [1 if x == 3 else 0 for x in eng[641689936]]
eng['641689937_Marks'] = [1 if x == 3 else 0 for x in eng[641689937]]

eng['641689938_Marks'] = [1 if x == 4 else 0 for x in eng[641689938]]

eng['641689939_Marks'] = [1 if x == 3 else 0 for x in eng[641689939]]
eng['641689940_Marks'] = [1 if x == 4 else 0 for x in eng[641689940]]
eng['641689941_Marks'] = [2 if x == 1 else 0 for x in eng[641689941]]
eng['641689942_Marks'] = [1 if x == 1 else 0 for x in eng[641689942]]
eng['641689943_Marks'] = [1 if x == 4 else 0 for x in eng[641689943]]
eng['641689944_Marks'] = [1 if x == 1 else 0 for x in eng[641689944]]
eng['641689945_Marks'] = [1 if x == 2 else 0 for x in eng[641689945]]
eng['641689946_Marks'] = [1 if x == 4 else 0 for x in eng[641689946]]
eng['641689947_Marks'] = [3 if x == 3 else 0 for x in eng[641689947]]

#calculating final Marks
#Math
math['Marks_Obatined'] = math['641690003_Marks']+math['641690004_Marks']+math['641690005_Marks']                         +math['641690006_Marks']+\
                         math['641690007_Marks']+math['641690008_Marks']+math['641690009_Marks']+ math['641690010_Marks']+math['641690011_Marks']+\
                         math['641690012_Marks']+math['641690013_Marks']+math['641690014_Marks']+ math['641690015_Marks']+math['641690016_Marks']+\
                         math['641690017_Marks']+math['641690018_Marks']+math['641690019_Marks']+math['641690020_Marks']+ math['641690024_Marks']                        +\
                         math['641690021_Marks']+math['641690022_Marks']+math['641690023_Marks']+ math['641690025_Marks']+math['641690026_Marks']+\
                         math['641690027_Marks']+math['641690028_Marks']+math['641690029_Marks']+ math['641690030_Marks']                        +\
                         math['641689948_Marks']+math['641689949_Marks']+math['641689950_Marks']+ math['641689951_Marks']+math['641689952_Marks']+\
                         math['641689953_Marks']+math['641689954_Marks']+math['641689955_Marks']+ math['641689956_Marks']+math['641689957_Marks']+\
                         math['641689958_Marks']+math['641689959_Marks']+math['641689960_Marks']+ math['641689961_Marks']+math['641689962_Marks']+\
                         math['641689963_Marks']+math['641689964_Marks']+math['641689965_Marks']+ math['641689966_Marks']+math['641689967_Marks']+\
                         math['641689968_Marks']+math['641689969_Marks']+math['641689970_Marks']+ math['641689971_Marks']+math['641689972_Marks']+\
                         math['641689973_Marks']+math['641689974_Marks']+math['641689975_Marks']                      



#Science
sci['Marks_Obatined'] = sci['641690085_Marks']+sci['641690086_Marks']+sci['641690087_Marks']+ sci['641690088_Marks']+sci['641690089_Marks']+\
                        sci['641690090_Marks']+sci['641690091_Marks']+sci['641690092_Marks']+ sci['641690093_Marks']+sci['641690094_Marks']+\
                        sci['641690095_Marks']+sci['641690096_Marks']+sci['641690097_Marks']+ sci['641690098_Marks']+sci['641690100_Marks']+\
                        sci['641690101_Marks']+sci['641690102_Marks']+sci['641690103_Marks']+ sci['641690104_Marks']+sci['641690104_Marks']+\
                        sci['641690109_Marks']+sci['641690110_Marks']+sci['641690111_Marks']                                               +\
                        sci['641690058_Marks']+sci['641690059_Marks']+sci['641690060_Marks']+ sci['641690061_Marks']+sci['641690062_Marks']+\
                        sci['641690062_Marks']+sci['641690063_Marks']+sci['641690064_Marks']+ sci['641690065_Marks']                       +\
                        sci['641690066_Marks']+sci['641690067_Marks']+sci['641690068_Marks']+ sci['641690069_Marks']+sci['641690070_Marks']+\
                        sci['641690071_Marks']+sci['641690072_Marks']+sci['641690073_Marks']+ sci['641690074_Marks']+sci['641690075_Marks']+\
                        sci['641690076_Marks']+sci['641690077_Marks']+sci['641690078_Marks']+ sci['641690079_Marks']+sci['641690080_Marks']+\
                        sci['641690081_Marks']+sci['641690082_Marks']+sci['641690083_Marks']+ sci['641690084_Marks']
                        
                       
#English
eng['Marks_Obatined'] = eng['641689913_Marks']+eng['641689914_Marks']+eng['641689915_Marks']+ eng['641689916_Marks']+eng['641689917_Marks']+\
                        eng['641689918_Marks']+eng['641689919_Marks']+eng['641689920_Marks']+ eng['641689921_Marks']+eng['641689922_Marks']+\
                        eng['641689923_Marks']+eng['641689924_Marks']+eng['641689925_Marks']+ eng['641689926_Marks']+eng['641689927_Marks']+\
                        eng['641689928_Marks']+eng['641689929_Marks']+eng['641689930_Marks']+ eng['641689931_Marks']+eng['641689932_Marks']+\
                        eng['641689933_Marks']+eng['641689934_Marks']+                        eng['641689936_Marks']+eng['641689937_Marks']+\
                        eng['641689938_Marks']+eng['641689939_Marks']+eng['641689940_Marks']+ eng['641689941_Marks']+eng['641689942_Marks']+\
                        eng['641689943_Marks']+eng['641689944_Marks']+eng['641689945_Marks']+ eng['641689946_Marks']+eng['641689947_Marks']
                       


#Dropping duplicates
#Math
df1 = math.copy()
df1 = df1.sort_values('Marks_Obatined')
df1 = df1.drop_duplicates('EnrollmentID', keep='last')

#Science
df2 = sci.copy()
df2 = df2.sort_values('Marks_Obatined')
df2 = df2.drop_duplicates('EnrollmentID', keep='last')
#English
df3 = eng.copy()
df3 = df3.sort_values('Marks_Obatined')
df3 = df3.drop_duplicates('EnrollmentID', keep='last')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:187: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# ##Uploading School Report

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-193d283d-c9ca-4a2b-a23b-8d9d44cfbf5d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-193d283d-c9ca-4a2b-a23b-8d9d44cfbf5d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
file = io.BytesIO(uploaded.get('SchoolReport_Semi Marathi_20221103_144303.xlsx'))
marathi_8th = pd.read_excel(file, 'MCQ Report')

# %% [markdown]
# ##Final Analysis

# %%
#Selecting 8th_standards Studnets
#Students
marathi_8th = marathi_8th[marathi_8th['Student/Teacher']== 'Student']
#Standars
marathi_8th = marathi_8th[marathi_8th['Course']== '8th Std Semi with Marathi Math-Sci']
#KEF Assessments
marathi_8th = marathi_8th[marathi_8th['Subject']== 'KEF Assessment']

#Selcting Math Assessments
marathi_8th_math = marathi_8th[(marathi_8th['Chapter']== 'Maths Baseline (Marathi)') | (marathi_8th['Chapter']== 'Maths Baseline (Semi)')]
marathi_8th_math= marathi_8th_math.drop_duplicates(subset=['EnrollmentID'], keep='last')
marathi_8th_math = marathi_8th_math[['School', 'EnrollmentID','StudentName', 'Chapter']]

#Selecting Science Assessments
marathi_8th_sci = marathi_8th[(marathi_8th['Chapter']== 'Science Baseline (Marathi)') | (marathi_8th['Chapter']== 'Science Baseline (Semi)')]
marathi_8th_sci=  marathi_8th_sci.drop_duplicates(subset=['EnrollmentID'], keep='last')
marathi_8th_sci = marathi_8th_sci[['School', 'EnrollmentID','StudentName', 'Chapter']] 

#Selecting English Assessments
marathi_8th_eng = marathi_8th[marathi_8th['Chapter']== 'English Baseline']
marathi_8th_eng=  marathi_8th_eng.drop_duplicates(subset=['EnrollmentID'], keep='last')
marathi_8th_eng = marathi_8th_eng[['School', 'EnrollmentID','StudentName', 'Chapter']] 


#Math
mathmathics   = pd.merge(marathi_8th_math,
                          df1,
                          on = 'EnrollmentID',
                          how = 'left'
                         )
#Science
science   = pd.merge(marathi_8th_sci,
                          df2,
                          on = 'EnrollmentID',
                          how = 'left'
                         )
#English
english   = pd.merge(marathi_8th_eng,
                          df3,
                          on = 'EnrollmentID',
                          how = 'left'
                         )

# %% [markdown]
# ##Downloads

# %%
mathmathics.to_excel('math_8th_standars_final_assessments.xlsx')
science.to_excel('science_8th_standars_final_assessments.xlsx')
english.to_excel('english_8th_standars_final_assessments.xlsx')
